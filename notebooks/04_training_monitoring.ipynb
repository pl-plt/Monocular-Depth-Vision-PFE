# %% [markdown]
# # 04 — Monitoring d'entraînement (Phase 4)
#
# **Objectif :** Suivre l'entraînement du Student en temps réel.
#
# **Vérifications :**
# - Courbes de loss (train + val)
# - Learning rate schedule
# - Détection overfitting (écart train/val)
# - Visualisation prédictions intermédiaires

# %%
import sys
sys.path.insert(0, '..')

import json
import matplotlib.pyplot as plt
from src.evaluation.visualization import DepthVisualizer

# %%
# TODO: Charger l'historique d'entraînement depuis le checkpoint
# import torch
# checkpoint = torch.load('outputs/checkpoints/best_model.pt', map_location='cpu')
# history = checkpoint['training_history']

# %%
# TODO: Tracer les courbes de loss
# viz = DepthVisualizer()
# viz.plot_training_history(history, save_path='outputs/visualizations/training_curves.png')

# %%
# TODO: Visualiser des prédictions intermédiaires
