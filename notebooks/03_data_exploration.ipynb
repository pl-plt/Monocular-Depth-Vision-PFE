# %% [markdown]
# # 03 — Exploration des données (Phase 2)
#
# **Objectif :** Visualiser et valider les datasets, vérifier le preprocessing.
#
# **Sanity checks :**
# - Visualiser 50 exemples aléatoires
# - Distribution tailles / ratios aspect
# - Histogramme valeurs pixels
# - Benchmark vitesse DataLoader (target: 500+ img/sec)

# %%
import sys
sys.path.insert(0, '..')

import matplotlib.pyplot as plt
import numpy as np
from src.data.preprocessing import validate_images, compute_dataset_stats, create_train_val_split

# %%
# TODO: Valider les images
# stats = validate_images('datasets/synthetic/hypersim/images', min_resolution=512)
# print(stats)

# %%
# TODO: Statistiques du dataset
# dataset_stats = compute_dataset_stats('datasets/synthetic/hypersim/images')
# print(dataset_stats)

# %%
# TODO: Benchmark vitesse DataLoader
# TODO: Visualiser exemples aléatoires (image + depth)
# TODO: Histogrammes de distribution
